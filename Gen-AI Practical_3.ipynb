# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
with open ('input.txt', 'r') as f:
  text = f.read().lower().split('\n')

  tokenizer = Tokenizer()
  tokenizer.fit_on_texts(text)
  total_words = len(tokenizer.word_index) + 1

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# ---------------------------------------
# 1. Read the document
# ---------------------------------------

with open("input.txt", "r", encoding="utf-8") as file:
    text = file.read().lower()

# ---------------------------------------
# 2. Tokenize the text
# ---------------------------------------

tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])

total_words = len(tokenizer.word_index) + 1

# ---------------------------------------
# 3. Create N-gram sequences
# ---------------------------------------

input_sequences = []

for line in text.split("\n"):
    token_list = tokenizer.texts_to_sequences([line])[0]

    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i + 1]
        input_sequences.append(n_gram_sequence)

# ---------------------------------------
# 4. Pad sequences
# ---------------------------------------

max_sequence_len = max(len(x) for x in input_sequences)

input_sequences = np.array(
    pad_sequences(
        input_sequences,
        maxlen=max_sequence_len,
        padding="pre"
    )
)

# ---------------------------------------
# 5. Separate input (X) and output (y)
# ---------------------------------------

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# ---------------------------------------
# 6. Build RNN model
# ---------------------------------------

model = Sequential()

model.add(
    Embedding(
        total_words,
        100,
        input_length=max_sequence_len - 1
    )
)

model.add(
    SimpleRNN(150)
)

model.add(
    Dense(total_words, activation="softmax")
)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

# ---------------------------------------
# 7. Train the model
# ---------------------------------------

model.fit(
    X,
    y,
    epochs=100,
    verbose=1
)

# ---------------------------------------
# 8. Function to predict next word
# ---------------------------------------

def predict_next_word(seed_text):

    token_list = tokenizer.texts_to_sequences([seed_text.lower()])[0]

    token_list = pad_sequences(
        [token_list],
        maxlen=max_sequence_len - 1,
        padding="pre"
    )

    predicted = model.predict(token_list, verbose=0)

    predicted_word_index = np.argmax(predicted, axis=1)[0]

    for word, index in tokenizer.word_index.items():
        if index == predicted_word_index:
            return word

    return "Unknown"


# ---------------------------------------
# 9. Take user input
# ---------------------------------------

while True:

    user_input = input(
        "\nEnter a sentence (type 'exit' to stop): "
    )

    if user_input.lower() == "exit":
        break

    next_word = predict_next_word(user_input)

    print("Predicted next word:", next_word)
# Out:
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.0190 - loss: 6.0727
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.0302 - loss: 5.8384
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.0397 - loss: 5.6615
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.0328 - loss: 5.6926
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.0389 - loss: 5.5737
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.0423 - loss: 5.5077
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.0509 - loss: 5.4169
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.0630 - loss: 5.1976
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.1019 - loss: 4.9909
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.1857 - loss: 4.6850
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.2694 - loss: 4.3310
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.3515 - loss: 3.9609
# Epoch 13/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4180 - loss: 3.5710
# Epoch 14/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.5501 - loss: 3.1792
# Epoch 15/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.6304 - loss: 2.7921
# Epoch 16/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6934 - loss: 2.4151
# Epoch 17/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7712 - loss: 2.0716
# Epoch 18/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.8247 - loss: 1.7404
# Epoch 19/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.8791 - loss: 1.4593
# Epoch 20/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9128 - loss: 1.2081
# Epoch 21/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9413 - loss: 0.9982
# Epoch 22/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9577 - loss: 0.8171
# Epoch 23/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9655 - loss: 0.6742
# Epoch 24/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9793 - loss: 0.5558
# Epoch 25/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9845 - loss: 0.4603
# Epoch 26/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9862 - loss: 0.3890
# Epoch 27/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9905 - loss: 0.3304
# Epoch 28/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9896 - loss: 0.2831
# Epoch 29/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9922 - loss: 0.2454
# Epoch 30/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9931 - loss: 0.2154
# Epoch 31/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9948 - loss: 0.1913
# Epoch 32/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9948 - loss: 0.1711
# Epoch 33/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9948 - loss: 0.1562
# Epoch 34/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9957 - loss: 0.1410
# Epoch 35/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9940 - loss: 0.1278
# Epoch 36/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9948 - loss: 0.1158
# Epoch 37/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9957 - loss: 0.1060
# Epoch 38/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9948 - loss: 0.1034
# Epoch 39/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9940 - loss: 0.0929
# Epoch 40/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9948 - loss: 0.0848
# Epoch 41/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9948 - loss: 0.0792
# Epoch 42/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9931 - loss: 0.0745
# Epoch 43/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9940 - loss: 0.0707
# Epoch 44/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9940 - loss: 0.0667
# Epoch 45/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9940 - loss: 0.0618
# Epoch 46/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9931 - loss: 0.0606
# Epoch 47/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9940 - loss: 0.0574
# Epoch 48/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9940 - loss: 0.0540
# Epoch 49/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9948 - loss: 0.0510
# Epoch 50/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9948 - loss: 0.0488
# Epoch 51/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9948 - loss: 0.0471
# Epoch 52/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9948 - loss: 0.0444
# Epoch 53/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9940 - loss: 0.0429
# Epoch 54/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9931 - loss: 0.0425
# Epoch 55/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9948 - loss: 0.0411
# Epoch 56/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9948 - loss: 0.0389
# Epoch 57/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9957 - loss: 0.0385
# Epoch 58/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9940 - loss: 0.0370
# Epoch 59/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9931 - loss: 0.0353
# Epoch 60/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9940 - loss: 0.0350
# Epoch 61/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9948 - loss: 0.0349
# Epoch 62/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9948 - loss: 0.0334
# Epoch 63/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - accuracy: 0.9948 - loss: 0.0312
# Epoch 64/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9940 - loss: 0.0307
# Epoch 65/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9948 - loss: 0.0303
# Epoch 66/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9940 - loss: 0.0291
# Epoch 67/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9948 - loss: 0.0283
# Epoch 68/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9948 - loss: 0.0437
# Epoch 69/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9940 - loss: 0.0369
# Epoch 70/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9948 - loss: 0.0309
# Epoch 71/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9957 - loss: 0.0295
# Epoch 72/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9948 - loss: 0.0266
# Epoch 73/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9948 - loss: 0.0255
# Epoch 74/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9948 - loss: 0.0263
# Epoch 75/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9948 - loss: 0.0246
# Epoch 76/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9940 - loss: 0.0227
# Epoch 77/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9940 - loss: 0.0233
# Epoch 78/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9948 - loss: 0.0219
# Epoch 79/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9940 - loss: 0.0237
# Epoch 80/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9940 - loss: 0.0231
# Epoch 81/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9957 - loss: 0.0225
# Epoch 82/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9940 - loss: 0.0219
# Epoch 83/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9940 - loss: 0.0212
# Epoch 84/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9931 - loss: 0.0211
# Epoch 85/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9948 - loss: 0.0204
# Epoch 86/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9940 - loss: 0.0212
# Epoch 87/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9948 - loss: 0.0186
# Epoch 88/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9948 - loss: 0.0193
# Epoch 89/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9931 - loss: 0.0189
# Epoch 90/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9948 - loss: 0.0270
# Epoch 91/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9914 - loss: 0.0376
# Epoch 92/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9836 - loss: 0.1249
# Epoch 93/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9948 - loss: 0.0567
# Epoch 94/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9948 - loss: 0.0316
# Epoch 95/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.9940 - loss: 0.0270
# Epoch 96/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 0.9948 - loss: 0.0246
# Epoch 97/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9940 - loss: 0.0241
# Epoch 98/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9940 - loss: 0.0231
# Epoch 99/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9948 - loss: 0.0212
# Epoch 100/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9948 - loss: 0.0195
#
# Enter a sentence (type 'exit' to stop): Natural
# Predicted next word: language
#
# Enter a sentence (type 'exit' to stop): language
# Predicted next word: is
#
# Enter a sentence (type 'exit' to stop): exit

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# ---------------------------------------
# 1. Read the document
# ---------------------------------------

with open("input.txt", "r", encoding="utf-8") as file:
    text = file.read().lower()

# ---------------------------------------
# 2. Tokenize the text
# ---------------------------------------

tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])

total_words = len(tokenizer.word_index) + 1

# ---------------------------------------
# 3. Create N-gram sequences
# ---------------------------------------

input_sequences = []

for line in text.split("\n"):
    token_list = tokenizer.texts_to_sequences([line])[0]

    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i + 1]
        input_sequences.append(n_gram_sequence)

# ---------------------------------------
# 4. Pad sequences
# ---------------------------------------

max_sequence_len = max(len(x) for x in input_sequences)

input_sequences = np.array(
    pad_sequences(
        input_sequences,
        maxlen=max_sequence_len,
        padding="pre"
    )
)

# ---------------------------------------
# 5. Separate input (X) and output (y)
# ---------------------------------------

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# ---------------------------------------
# 6. Build RNN model
# ---------------------------------------

model = Sequential()

model.add(
    Embedding(
        total_words,
        100,
        input_length=max_sequence_len - 1
    )
)

model.add(
    SimpleRNN(150)
)

model.add(
    Dense(total_words, activation="softmax")
)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

# ---------------------------------------
# 7. Train the model
# ---------------------------------------

model.fit(
    X,
    y,
    epochs=100,
    verbose=1
)

# ---------------------------------------
# 8. Function to predict next word
# ---------------------------------------

def predict_next_word(seed_text):

    token_list = tokenizer.texts_to_sequences([seed_text.lower()])[0]

    token_list = pad_sequences(
        [token_list],
        maxlen=max_sequence_len - 1,
        padding="pre"
    )

    predicted = model.predict(token_list, verbose=0)

    predicted_word_index = np.argmax(predicted, axis=1)[0]

    for word, index in tokenizer.word_index.items():
        if index == predicted_word_index:
            return word

    return "Unknown"


# ---------------------------------------
# 9. Take user input
# ---------------------------------------

while True:

    user_input = input(
        "\nEnter a sentence (type 'exit' to stop): "
    )

    if user_input.lower() == "exit":
        break

    next_word = predict_next_word(user_input)

    print("Predicted next word:", next_word)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.0247 - loss: 5.9783
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.0494 - loss: 5.6417
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.0494 - loss: 5.5481
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.0494 - loss: 5.4714
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.0494 - loss: 5.3622
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.0773 - loss: 5.1818
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.0881 - loss: 5.0693
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.1450 - loss: 4.7215
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.1923 - loss: 4.3439
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.2836 - loss: 3.9536
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.3845 - loss: 3.5741
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.4737 - loss: 3.1934
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5908 - loss: 2.7958
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6992 - loss: 2.4185
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7809 - loss: 2.0657
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8528 - loss: 1.7426
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.8947 - loss: 1.4723
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9334 - loss: 1.2114
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.9592 - loss: 0.9910
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9689 - loss: 0.8205
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9764 - loss: 0.6725
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9850 - loss: 0.5580
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9850 - loss: 0.4642
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9882 - loss: 0.3923
# Epoch 25/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.9882 - loss: 0.3321
# Epoch 26/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9903 - loss: 0.2863
# Epoch 27/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9925 - loss: 0.2508
# Epoch 28/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9936 - loss: 0.2206
# Epoch 29/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9914 - loss: 0.1994
# Epoch 30/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9936 - loss: 0.1764
# Epoch 31/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9946 - loss: 0.1585
# Epoch 32/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.9936 - loss: 0.1432
# Epoch 33/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9946 - loss: 0.1328
# Epoch 34/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9936 - loss: 0.1219
# Epoch 35/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9925 - loss: 0.1132
# Epoch 36/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9914 - loss: 0.1059
# Epoch 37/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9936 - loss: 0.0978
# Epoch 38/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9925 - loss: 0.0907
# Epoch 39/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9936 - loss: 0.0851
# Epoch 40/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9946 - loss: 0.0800
# Epoch 41/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9936 - loss: 0.0764
# Epoch 42/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9968 - loss: 0.0818
# Epoch 43/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9914 - loss: 0.1276
# Epoch 44/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9946 - loss: 0.0812
# Epoch 45/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9936 - loss: 0.0683
# Epoch 46/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9860 - loss: 0.1083
# Epoch 47/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.9828 - loss: 0.2182
# Epoch 48/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9914 - loss: 0.1421
# Epoch 49/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9925 - loss: 0.0839
# Epoch 50/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0652
# Epoch 51/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9914 - loss: 0.0584
# Epoch 52/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9946 - loss: 0.0564
# Epoch 53/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9946 - loss: 0.0546
# Epoch 54/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9925 - loss: 0.0520
# Epoch 55/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.9936 - loss: 0.0460
# Epoch 56/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9936 - loss: 0.0431
# Epoch 57/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9925 - loss: 0.0419
# Epoch 58/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.9925 - loss: 0.0390
# Epoch 59/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9946 - loss: 0.0370
# Epoch 60/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9903 - loss: 0.0361
# Epoch 61/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9936 - loss: 0.0355
# Epoch 62/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9925 - loss: 0.0337
# Epoch 63/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9925 - loss: 0.0330
# Epoch 64/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9936 - loss: 0.0339
# Epoch 65/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9946 - loss: 0.0330
# Epoch 66/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.9893 - loss: 0.0344
# Epoch 67/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9914 - loss: 0.0310
# Epoch 68/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9925 - loss: 0.0291
# Epoch 69/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.9936 - loss: 0.0286
# Epoch 70/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9925 - loss: 0.0272
# Epoch 71/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0276
# Epoch 72/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0261
# Epoch 73/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9936 - loss: 0.0264
# Epoch 74/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9925 - loss: 0.0264
# Epoch 75/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.9936 - loss: 0.0251
# Epoch 76/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9936 - loss: 0.0253
# Epoch 77/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0236
# Epoch 78/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0242
# Epoch 79/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9936 - loss: 0.0232
# Epoch 80/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9946 - loss: 0.0232
# Epoch 81/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9936 - loss: 0.0237
# Epoch 82/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9936 - loss: 0.0225
# Epoch 83/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.9925 - loss: 0.0220
# Epoch 84/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9936 - loss: 0.0219
# Epoch 85/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9925 - loss: 0.0218
# Epoch 86/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9914 - loss: 0.0220
# Epoch 87/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.9936 - loss: 0.0215
# Epoch 88/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9925 - loss: 0.0203
# Epoch 89/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.9914 - loss: 0.0216
# Epoch 90/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9925 - loss: 0.0206
# Epoch 91/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9925 - loss: 0.0222
# Epoch 92/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9925 - loss: 0.0206
# Epoch 93/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9925 - loss: 0.0196
# Epoch 94/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9914 - loss: 0.0200
# Epoch 95/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.9936 - loss: 0.0205
# Epoch 96/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9925 - loss: 0.0211
# Epoch 97/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9914 - loss: 0.0191
# Epoch 98/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9914 - loss: 0.0293
# Epoch 99/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9946 - loss: 0.0251
# Epoch 100/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9946 - loss: 0.0235
#
# Enter a sentence (type 'exit' to stop): Natural
# Predicted next word: language
#
# Enter a sentence (type 'exit' to stop): Processing
# Predicted next word: nlp
#
# Enter a sentence (type 'exit' to stop): exit

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense

# ---------------------------------------
# 1. Read the document
# ---------------------------------------

with open("input.txt", "r", encoding="utf-8") as file:
    text = file.read().lower()

# ---------------------------------------
# 2. Tokenize the text
# ---------------------------------------

tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])

total_words = len(tokenizer.word_index) + 1

# ---------------------------------------
# 3. Create N-gram sequences
# ---------------------------------------

input_sequences = []

for line in text.split("\n"):
    token_list = tokenizer.texts_to_sequences([line])[0]

    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i + 1]
        input_sequences.append(n_gram_sequence)

# ---------------------------------------
# 4. Pad sequences
# ---------------------------------------

max_sequence_len = max(len(x) for x in input_sequences)

input_sequences = np.array(
    pad_sequences(
        input_sequences,
        maxlen=max_sequence_len,
        padding="pre"
    )
)

# ---------------------------------------
# 5. Separate input (X) and output (y)
# ---------------------------------------

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# ---------------------------------------
# 6. Build RNN model
# ---------------------------------------

model = Sequential()

model.add(
    Embedding(
        total_words,
        100,
        input_length=max_sequence_len - 1
    )
)

model.add(
    SimpleRNN(150)
)

model.add(
    Dense(total_words, activation="softmax")
)

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

# ---------------------------------------
# 7. Train the model
# ---------------------------------------

model.fit(
    X,
    y,
    epochs=100,
    verbose=1
)

# ---------------------------------------
# 8. Function to predict next word
# ---------------------------------------

def predict_next_word(seed_text):

    token_list = tokenizer.texts_to_sequences([seed_text.lower()])[0]

    token_list = pad_sequences(
        [token_list],
        maxlen=max_sequence_len - 1,
        padding="pre"
    )

    predicted = model.predict(token_list, verbose=0)

    predicted_word_index = np.argmax(predicted, axis=1)[0]

    for word, index in tokenizer.word_index.items():
        if index == predicted_word_index:
            return word

    return "Unknown"


# ---------------------------------------
# 9. Take user input
# ---------------------------------------

while True:

    user_input = input(
        "\nEnter a sentence (type 'exit' to stop): "
    )

    if user_input.lower() == "exit":
        break

    next_word = predict_next_word(user_input)

    print("Predicted next word:", next_word)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.0054 - loss: 6.0595
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.0247 - loss: 5.9772
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.0559 - loss: 5.7118
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.0559 - loss: 5.4963
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.0526 - loss: 5.3326
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.0666 - loss: 5.1469
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.1085 - loss: 4.8951
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.1547 - loss: 4.5852
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.2137 - loss: 4.2524
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.3426 - loss: 3.8530
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.4533 - loss: 3.4403
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5467 - loss: 3.0492
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6606 - loss: 2.6426
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.7497 - loss: 2.2494
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.8185 - loss: 1.9145
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8840 - loss: 1.5974
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8142 - loss: 1.6856
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9119 - loss: 1.3340
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9581 - loss: 0.9597
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9721 - loss: 0.7722
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.9774 - loss: 0.6277
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9817 - loss: 0.5165
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9860 - loss: 0.4483
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9882 - loss: 0.3767
# Epoch 25/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9871 - loss: 0.3226
# Epoch 26/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9882 - loss: 0.2796
# Epoch 27/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9903 - loss: 0.2436
# Epoch 28/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.9893 - loss: 0.2174
# Epoch 29/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9903 - loss: 0.1946
# Epoch 30/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9903 - loss: 0.1738
# Epoch 31/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9925 - loss: 0.1583
# Epoch 32/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.1439
# Epoch 33/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.9925 - loss: 0.1341
# Epoch 34/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9936 - loss: 0.1245
# Epoch 35/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.9925 - loss: 0.1130
# Epoch 36/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9914 - loss: 0.1050
# Epoch 37/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9914 - loss: 0.0977
# Epoch 38/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9936 - loss: 0.0916
# Epoch 39/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9925 - loss: 0.0856
# Epoch 40/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0807
# Epoch 41/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9925 - loss: 0.0765
# Epoch 42/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.9925 - loss: 0.0714
# Epoch 43/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9936 - loss: 0.0680
# Epoch 44/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9925 - loss: 0.0652
# Epoch 45/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0618
# Epoch 46/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9936 - loss: 0.0588
# Epoch 47/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9914 - loss: 0.0577
# Epoch 48/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9925 - loss: 0.0551
# Epoch 49/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.9914 - loss: 0.0526
# Epoch 50/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9936 - loss: 0.0499
# Epoch 51/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9936 - loss: 0.0488
# Epoch 52/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9925 - loss: 0.0468
# Epoch 53/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9925 - loss: 0.0456
# Epoch 54/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9946 - loss: 0.0435
# Epoch 55/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9936 - loss: 0.0423
# Epoch 56/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.9946 - loss: 0.0414
# Epoch 57/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9925 - loss: 0.0392
# Epoch 58/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9936 - loss: 0.0387
# Epoch 59/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9914 - loss: 0.0380
# Epoch 60/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9893 - loss: 0.0373
# Epoch 61/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0364
# Epoch 62/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9903 - loss: 0.0340
# Epoch 63/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.9914 - loss: 0.0336
# Epoch 64/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9946 - loss: 0.0332
# Epoch 65/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9936 - loss: 0.0323
# Epoch 66/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9936 - loss: 0.0304
# Epoch 67/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9936 - loss: 0.0303
# Epoch 68/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9925 - loss: 0.0299
# Epoch 69/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.9925 - loss: 0.0295
# Epoch 70/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9914 - loss: 0.0567
# Epoch 71/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9914 - loss: 0.0504
# Epoch 72/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9936 - loss: 0.0381
# Epoch 73/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0327
# Epoch 74/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9914 - loss: 0.0306
# Epoch 75/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9914 - loss: 0.0312
# Epoch 76/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9925 - loss: 0.0296
# Epoch 77/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9936 - loss: 0.0274
# Epoch 78/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0266
# Epoch 79/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9925 - loss: 0.0257
# Epoch 80/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.9925 - loss: 0.0257
# Epoch 81/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9914 - loss: 0.0233
# Epoch 82/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9925 - loss: 0.0233
# Epoch 83/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9936 - loss: 0.0227
# Epoch 84/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9925 - loss: 0.0230
# Epoch 85/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0210
# Epoch 86/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9925 - loss: 0.0226
# Epoch 87/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9914 - loss: 0.0214
# Epoch 88/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.9925 - loss: 0.0214
# Epoch 89/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.9914 - loss: 0.0213
# Epoch 90/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.9925 - loss: 0.0207
# Epoch 91/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9893 - loss: 0.0211
# Epoch 92/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0205
# Epoch 93/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9903 - loss: 0.0215
# Epoch 94/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9914 - loss: 0.0213
# Epoch 95/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0201
# Epoch 96/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9936 - loss: 0.0201
# Epoch 97/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9914 - loss: 0.0236
# Epoch 98/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9914 - loss: 0.0280
# Epoch 99/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9936 - loss: 0.0228
# Epoch 100/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9925 - loss: 0.0215
#
# Enter a sentence (type 'exit' to stop): Natural
# Predicted next word: language
#
# Enter a sentence (type 'exit' to stop): exit
